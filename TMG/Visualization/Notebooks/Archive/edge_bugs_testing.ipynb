# %%
from dredFISH.Analysis.TissueGraph import *
from dredFISH.Visualization.Viz import *

import matplotlib.pyplot as plt

# %%
TMG = TissueMultiGraph('/home/jperrie/Documents/dredFISH/dredFISH/Analysis/Notebooks/TMG_dev5.pkl')
TMG.add_geoms()

# %%
V = RasterMap(TMG, lvl=0)
V.set_view()
V.plot()
plt.show()

# %%
V = RasterMap(TMG, lvl=3)
V.set_view()
V.plot()
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,20))

V = RandomPolygonColorByTypeWithLines(TMG,lvl=3)
V.set_view()
V.plot_lines()
mx = np.max(np.array(TMG.Geoms['BoundingBox'].exterior.xy).T,axis=0)
mn = np.min(np.array(TMG.Geoms['BoundingBox'].exterior.xy).T,axis=0)
ax.set_xlim(mn[0],mx[0])
ax.set_ylim(mn[1],mx[1])
ax.axis('off')
plt.show()

# %%
V = RandomPolygonColorByTypeWithLines(TMG,lvl=3)
V.set_view()
V.plot()
plt.show()
# Out:
# /home/jperrie/Documents/dredFISH/dredFISH/Visualization/Viz.py:200: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   segs = np.array(segs)
